# %%
import part1
import part2

# %% [markdown]
# # Part1: Identifying cis-eQTLs in 1000 Genomes LCLs

# %% [markdown]
# ## Chromosome 1

# %%
chr1 = part1.ciseQTL(1)
chr1
# Out:
# Summary statistics filed saved to './ciseqtls_sumstats/sumstats_1'
#         Chr    Gene           SNP    beta_0    beta_1      R_sq  \
# 0         1  SAMD11   rs3094315_A  3.289710  0.082625  0.002426
# 1         1  SAMD11   rs3131972_G  3.291351  0.081776  0.002384
# 2         1  SAMD11   rs3131969_G  3.276884  0.086575  0.002388
# 3         1  SAMD11   rs1048488_T  3.293820  0.080140  0.002332
# 4         1  SAMD11   rs3115850_C  3.294987  0.079574  0.002307
# ...     ...     ...           ...       ...       ...       ...
# 639975    1   PGBD2   rs4926502_G  1.416963  0.148219  0.009381
# 639976    1   PGBD2   rs6704311_G  1.741450 -0.017717  0.000391
# 639977    1   PGBD2  rs34013644_T  1.730611 -0.011718  0.000130
# 639978    1   PGBD2  rs12746903_T  1.905123 -0.099312  0.001828
# 639979    1   PGBD2  rs12726733_C  1.726229 -0.009268  0.000056
#
#         Standard Error   P-value
# 0             0.090597  0.362409
# 1             0.090448  0.366567
# ...

# %%
part1.cis_plot('./ciseqtls_sumstats/sumstats_1', 'FLAD1')
# Out:
# Statistically significant SNPs for FLAD1 on Chromsome 1 are: rs1127313_G rs1127311_G rs9427094_C rs903323_C rs3766922_T rs12125166_C rs6699825_A rs11264233_G rs9426832_A rs7547072_C rs954213_C rs2036627_T rs1506982_A rs2798601_G rs1106235_G rs10752609_G rs1218578_G rs7528532_C rs10908448_C rs4845690_T rs877343_A rs4845693_C rs6699043_T rs2335408_G rs11264302_A rs3765087_A rs11264303_C rs12743272_G rs35902694_G rs11264306_A rs1001848_A rs3766916_C rs1462855_T rs2306124_G rs7534162_A rs10908454_G rs4971073_G rs6427184_A rs4971092_T rs7549186_T

# %% [markdown]
# ## Chromosome 21

# %%
chr21 = part1.ciseQTL(21)
chr21
# Out:
# Summary statistics filed saved to './ciseqtls_sumstats/sumstats_21'
#        Chr   Gene          SNP     beta_0    beta_1          R_sq  \
# 0       21   LIPI  rs3965725_A   0.033759  0.002269  1.814565e-03
# 1       21   LIPI  rs2775537_G   0.036462 -0.000011  4.921850e-08
# 2       21   LIPI  rs2261645_G   0.037504 -0.000934  3.446541e-04
# 3       21   LIPI  rs2742158_C   0.037504 -0.000934  3.446541e-04
# 4       21   LIPI  rs2260810_A   0.037504 -0.000934  3.446541e-04
# ...    ...    ...          ...        ...       ...           ...
# 77806   21  PRMT2  rs2838986_G  23.358198  0.303575  8.378273e-04
# 77807   21  PRMT2  rs8133966_G  24.042126 -0.122954  1.374851e-04
# 77808   21  PRMT2   rs914243_A  24.172920 -0.253575  8.318151e-04
# 77809   21  PRMT2  rs2838988_G  24.042126 -0.122954  1.374851e-04
# 77810   21  PRMT2  rs4819147_C  24.294291 -0.263758  4.624785e-04
#
#        Standard Error   P-value
# 0            0.002877  0.430959
# 1            0.002704  0.996729
# ...

# %%
part1.cis_plot('./ciseqtls_sumstats/sumstats_21', 'DOPEY2')
# Out:
# Statistically significant SNPs for DOPEY2 on Chromsome 21 are: rs2284575_G rs2834531_G rs2251817_C rs2834617_T rs16992322_C rs8131520_T rs8132222_A rs2834639_G rs16992400_T rs2298351_G rs2298352_T rs2300400_T rs9976623_T rs2834660_C rs2186347_C rs10854374_A rs2834662_T rs1475840_A rs2248313_C rs7282762_G rs8126567_C rs2834694_C rs2834695_C rs2834698_C rs2834699_A rs2834701_A rs2834807_A rs2834810_C rs2834812_C rs2834819_C rs2834843_C rs2834844_T rs2834846_C rs10427505_C rs11088316_G rs2834885_A rs9984369_T rs2142049_C rs2178817_A rs13048915_A rs2834896_C

# %% [markdown]
# ## Chromosome 22

# %%
chr22 = part1.ciseQTL(22)
chr22
# Out:
# Summary statistics filed saved to './ciseqtls_sumstats/sumstats_22'
#         Chr    Gene           SNP     beta_0    beta_1      R_sq  \
# 0        22  IL17RA   rs7287144_A   3.782866  0.047428  0.000473
# 1        22  IL17RA   rs5748662_G   3.908175 -0.040201  0.000365
# 2        22  IL17RA   rs5994034_C   3.428567  0.237199  0.005930
# 3        22  IL17RA   rs4010554_C   3.797086  0.038085  0.000320
# 4        22  IL17RA   rs4010558_G   3.797086  0.038085  0.000320
# ...     ...     ...           ...        ...       ...       ...
# 162840   22  RABL2B  rs13056621_G  10.790416  0.221600  0.001953
# 162841   22  RABL2B   rs3865766_C  11.629950 -0.423202  0.016176
# 162842   22  RABL2B   rs3888396_T  10.346192  0.484334  0.010872
# 162843   22  RABL2B   rs2238837_A  11.429146 -0.198666  0.003100
# 162844   22  RABL2B  rs28729663_G  12.160286 -0.589469  0.015546
#
#         Standard Error   P-value
# 0             0.117846  0.687600
# 1             0.113810  0.724133
# ...

# %%
part1.cis_plot('./ciseqtls_sumstats/sumstats_22', 'PACSIN2')
# Out:
# Statistically significant SNPs for PACSIN2 on Chromsome 22 are: rs5751191_C rs13053833_C rs2269665_G rs6519301_A rs129857_T rs133330_G rs133335_A rs4822084_C rs5758566_A rs1063392_A rs133367_T rs133373_G rs133376_C rs133383_C rs7245_A rs2284087_C rs1801311_G rs4147638_G rs5996109_A rs6002607_T rs6002609_C rs6002616_A rs2413669_A rs5751216_T rs6002621_A rs6002623_G rs11090076_T rs5758589_G rs764481_G rs2142694_G rs2223273_T rs5758649_C rs5758706_C rs2071846_G rs6002935_G rs9611880_C rs738532_C rs4634034_A rs9623697_T rs5758941_A rs1997885_T rs5751372_T rs1807591_G rs5758948_G rs5758951_A rs738535_C rs1018448_C rs2024645_C rs9607955_A rs5758965_C rs9607961_C rs5758972_C rs8136252_C rs4822203_T rs5751386_C rs6002963_A rs3788599_C rs5758988_T rs5758991_A rs738536_G rs4822208_C rs5759002_G rs7074_G rs4822211_G rs13433641_T rs9607973_A rs2073199_A rs2899365_C rs8139013_G rs2273143_C rs5751399_C rs5759012_A rs12166809_G rs5759013_G rs9611958_G rs1076118_C rs4820494_T rs4822225_T rs7364152_G
# ...

# %% [markdown]
# # Part 2: Generate PRS Scores for Multiple Diseases

# %% [markdown]
# ## Diabetes Mellitus

# %%
diabetes = part2.prs('diabetes_gwas.tsv', 'diabetes')
diabetes
# Out:
# PLINK v2.0.0-a.6 M1 (14 Oct 2024)                  cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./PRS_diabetes.log.
# Options in effect:
#   --bfile ./b_diabetes/1000G_eur_PRS
#   --out ./PRS_diabetes
#   --score ./score_file_diabetes.txt 1 2 3
#
# Start time: Wed Dec  4 15:39:18 2024
# 8192 MiB RAM detected; reserving 4096 MiB for main workspace.
# Using up to 8 compute threads.
# 490 samples (0 females, 0 males, 490 ambiguous; 490 founders) loaded from
# ./b_diabetes/1000G_eur_PRS.fam.
# 875 variants loaded from ./b_diabetes/1000G_eur_PRS.bim.
# Note: No phenotype data present.
# Calculating allele frequencies... done.
# --score: 756 variants processed.
# --score: Results written to ./PRS_diabetes.sscore .
# End time: Wed Dec  4 15:39:18 2024
# ...
# mismatching allele codes.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# ...

# %% [markdown]
# ## Heart Disease

# %%
heart = part2.prs('heart_gwas.tsv', 'heart', color = "#6a994e")
# Out:
# PLINK v2.0.0-a.6 M1 (14 Oct 2024)                  cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./PRS_heart.log.
# Options in effect:
#   --bfile ./b_heart/1000G_eur_PRS
#   --out ./PRS_heart
#   --score ./score_file_heart.txt 1 2 3
#
# Start time: Wed Dec  4 15:39:19 2024
# 8192 MiB RAM detected; reserving 4096 MiB for main workspace.
# Using up to 8 compute threads.
# 490 samples (0 females, 0 males, 490 ambiguous; 490 founders) loaded from
# ./b_heart/1000G_eur_PRS.fam.
# 699 variants loaded from ./b_heart/1000G_eur_PRS.bim.
# Note: No phenotype data present.
# Calculating allele frequencies... done.
# --score: 611 variants processed.
# --score: Results written to ./PRS_heart.sscore .
# End time: Wed Dec  4 15:39:19 2024
# ...
# mismatching allele codes.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)

# %% [markdown]
# ## Parkinson's Disease

# %%
parkinsons = part2.prs('parkinsons_gwas.tsv', 'parkinsons', color='#967aa1')
# Out:
# PLINK v2.0.0-a.6 M1 (14 Oct 2024)                  cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./PRS_parkinsons.log.
# Options in effect:
#   --bfile ./b_parkinsons/1000G_eur_PRS
#   --out ./PRS_parkinsons
#   --score ./score_file_parkinsons.txt 1 2 3
#
# Start time: Wed Dec  4 15:39:19 2024
# 8192 MiB RAM detected; reserving 4096 MiB for main workspace.
# Using up to 8 compute threads.
# 490 samples (0 females, 0 males, 490 ambiguous; 490 founders) loaded from
# ./b_parkinsons/1000G_eur_PRS.fam.
# 114 variants loaded from ./b_parkinsons/1000G_eur_PRS.bim.
# Note: No phenotype data present.
# Calculating allele frequencies... done.
# --score: 97 variants processed.
# --score: Results written to ./PRS_parkinsons.sscore .
# End time: Wed Dec  4 15:39:19 2024
# ...
# mismatching allele codes.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)

# %% [markdown]
# ## Skin Cancer

# %%
skinCancer = part2.prs('skin_cancer_gwas.tsv', 'SkinCancer', color='#ee9b00')
skinCancer
# Out:
# PLINK v2.0.0-a.6 M1 (14 Oct 2024)                  cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./PRS_SkinCancer.log.
# Options in effect:
#   --bfile ./b_SkinCancer/1000G_eur_PRS
#   --out ./PRS_SkinCancer
#   --score ./score_file_SkinCancer.txt 1 2 3
#
# Start time: Wed Dec  4 15:39:20 2024
# 8192 MiB RAM detected; reserving 4096 MiB for main workspace.
# Using up to 8 compute threads.
# 490 samples (0 females, 0 males, 490 ambiguous; 490 founders) loaded from
# ./b_SkinCancer/1000G_eur_PRS.fam.
# 131 variants loaded from ./b_SkinCancer/1000G_eur_PRS.bim.
# Note: No phenotype data present.
# Calculating allele frequencies... done.
# --score: 122 variants processed.
# --score: Results written to ./PRS_SkinCancer.sscore .
# End time: Wed Dec  4 15:39:20 2024
# ...
# mismatching allele codes.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
# ...

# %% [markdown]
# ## Arthritis

# %%
arthritis = part2.prs('arthritis_gwas.tsv', 'arthritis', color='#1b263b')
# Out:
# PLINK v2.0.0-a.6 M1 (14 Oct 2024)                  cog-genomics.org/plink/2.0/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ./PRS_arthritis.log.
# Options in effect:
#   --bfile ./b_arthritis/1000G_eur_PRS
#   --out ./PRS_arthritis
#   --score ./score_file_arthritis.txt 1 2 3
#
# Start time: Wed Dec  4 15:39:21 2024
# 8192 MiB RAM detected; reserving 4096 MiB for main workspace.
# Using up to 8 compute threads.
# 490 samples (0 females, 0 males, 490 ambiguous; 490 founders) loaded from
# ./b_arthritis/1000G_eur_PRS.fam.
# 443 variants loaded from ./b_arthritis/1000G_eur_PRS.bim.
# Note: No phenotype data present.
# Calculating allele frequencies... done.
# --score: 362 variants processed.
# --score: Results written to ./PRS_arthritis.sscore .
# End time: Wed Dec  4 15:39:21 2024
# ...
# mismatching allele codes.
# (Add the 'list-variants' modifier to see which variants were actually used for
# scoring.)
